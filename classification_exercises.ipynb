# %%
# for viz
import matplotlib.pyplot as plt
# for statistics
from scipy import stats
# for numerical data:
import numpy as np
from pydataset import data
import env
import acquire as ac
import pandas as pd

# %% [markdown]
# # Question 4
#
# In a jupyter notebook, classification_exercises.ipynb, use a python module (pydata or seaborn datasets) containing datasets as a source from the iris data. Create a pandas dataframe, df_iris, from this data.

# %%
df_iris = data('iris')
df_iris.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %%
df_iris.shape
# Out:
# (150, 5)

# %%
df_iris.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
df_iris.dtypes
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
df_iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Question 5
#
# Read the data from this google sheet into a dataframe, df_google.

# %%
import pandas as pd

sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df_googlesheet = pd.read_csv(csv_export_url)
df_googlesheet.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df_googlesheet.shape
# Out:
# (891, 12)

# %%
df_googlesheet.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_googlesheet.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_googlesheet.value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                                                  Sex     Age   SibSp  Parch  Ticket    Fare      Cabin  Embarked
# 2            1         1       Cumings, Mrs. John Bradley (Florence Briggs Thayer)   female  38.0  1      0      PC 17599  71.2833   C85    C           1
# 572          1         1       Appleton, Mrs. Edward Dale (Charlotte Lamson)         female  53.0  2      0      11769     51.4792   C101   S           1
# 578          1         1       Silvey, Mrs. William Baird (Alice Munger)             female  39.0  1      0      13507     55.9000   E44    S           1
# 582          1         1       Thayer, Mrs. John Borland (Marian Longstreth Morris)  female  39.0  1      1      17421     110.8833  C68    C           1
# 584          0         1       Ross, Mr. John Hugo                                   male    36.0  0      0      13049     40.1250   A10    C           1
# ...

# %% [markdown]
# # Question 6
#
# Download the previous exercise's file into an excel (File → Download → Microsoft Excel). Read the downloaded file into a dataframe named df_excel.

# %%
df_exel = pd.read_excel('train.xlsx')
df_excel_sample = df_exel.head(100)

# %%
df_exel.head(100)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
df_titanic.to_csv('Titanic_data.csv', index=False)

# %%
pd.read_csv('Titanic_data.csv')
# Out:
#       Unnamed: 0      class     age    sex survived
# 0              1  1st class  adults    man      yes
# 1              2  1st class  adults    man      yes
# 2              3  1st class  adults    man      yes
# 3              4  1st class  adults    man      yes
# 4              5  1st class  adults    man      yes
# ...          ...        ...     ...    ...      ...
# 1311        1312  3rd class   child  women       no
# 1312        1313  3rd class   child  women       no
# 1313        1314  3rd class   child  women       no
# 1314        1315  3rd class   child  women       no
# 1315        1316  3rd class   child  women       no
#
# [1316 rows x 5 columns]

# %%
df_titanic.to_csv
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df_titanic.to_csv --help
#
# TypeError: bad operand type for unary -: '_Helper'

# %% [markdown]
# # ****************************Data Preperation ***************************
#
# # Using the Iris Data:
#
#
#
# ### Use the function defined in acquire.py to load the iris data.

# %%
ac.get_iris_data()
iris_db = ac.get_iris_data()
iris_db.sample(3)
# Out:
#      species_id species_name  measurement_id  sepal_length  sepal_width  \
# 105           3    virginica             106           7.6          3.0
# 110           3    virginica             111           6.5          3.2
# 8             1       setosa               9           4.4          2.9
#
#      petal_length  petal_width
# 105           6.6          2.1
# 110           5.1          2.0
# 8             1.4          0.2

# %% [markdown]
# ### Drop the species_id and measurement_id columns.

# %%
cols_to_drop = ['species_id', 'measurement_id']
iris_db = iris_db.drop(columns=cols_to_drop)
iris_db.sample(3)
# Out:
#    species_name  sepal_length  sepal_width  petal_length  petal_width
# 25       setosa           5.0          3.0           1.6          0.2
# 53   versicolor           5.5          2.3           4.0          1.3
# 7        setosa           5.0          3.4           1.5          0.2

# %% [markdown]
# ### Rename the species_name column to just species.

# %%
iris_db = iris_db.rename(columns={'species_name': 'species'})
iris_db.sample(3)
# Out:
#      species_id     species  measurement_id  sepal_length  sepal_width  \
# 42            1      setosa              43           4.4          3.2
# 74            2  versicolor              75           6.4          2.9
# 129           3   virginica             130           7.2          3.0
#
#      petal_length  petal_width
# 42            1.3          0.2
# 74            4.3          1.3
# 129           5.8          1.6

# %% [markdown]
# ### Create dummy variables of the species name and concatenate onto the iris dataframe. (This is for practice, we don't always have to encode the target, but if we used species as a feature, we would need to encode it).

# %%
iris_db.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
# Using drop_first leaves sex_male, embark_town_Queenstown, and embark_town_Southampton.

pd.get_dummies(iris_db.species).astype(int)

dummy_df = pd.get_dummies(iris_db[['species']], drop_first=True).astype(int)
dummy_df.shape
# Out:
# (150, 2)

# %%
iris_db = pd.concat([iris_db, dummy_df], axis=1)
iris_db.sample(10)
# Out:
#         species  sepal_length  sepal_width  petal_length  petal_width  \
# 99   versicolor           5.7          2.8           4.1          1.3
# 82   versicolor           5.8          2.7           3.9          1.2
# 139   virginica           6.9          3.1           5.4          2.1
# 112   virginica           6.8          3.0           5.5          2.1
# 100   virginica           6.3          3.3           6.0          2.5
# 11       setosa           4.8          3.4           1.6          0.2
# 14       setosa           5.8          4.0           1.2          0.2
# 33       setosa           5.5          4.2           1.4          0.2
# 101   virginica           5.8          2.7           5.1          1.9
# 60   versicolor           5.0          2.0           3.5          1.0
#
#      species_versicolor  species_virginica
# 99                    1                  0
# 82                    1                  0
# 139                   0                  1
# ...

# %%
iris_db.dtypes
# Out:
# species                object
# sepal_length          float64
# sepal_width           float64
# petal_length          float64
# petal_width           float64
# species_versicolor      int64
# species_virginica       int64
# dtype: object

# %%
def prep_iris(df):
    df = df.drop(columns= ['species_id', 'measurement_id'])
    df = df.rename(columns={'species_name': 'species'})
    dummy_df = pd.get_dummies(df[['species']], drop_first=True).astype(int)
    df = pd.concat([df, dummy_df], axis=1)
    return df

# %%
fresh_iris = ac.get_iris_data()

# %%
prep_iris(fresh_iris)
# Out:
#         species  sepal_length  sepal_width  petal_length  petal_width  \
# 0        setosa           5.1          3.5           1.4          0.2
# 1        setosa           4.9          3.0           1.4          0.2
# 2        setosa           4.7          3.2           1.3          0.2
# 3        setosa           4.6          3.1           1.5          0.2
# 4        setosa           5.0          3.6           1.4          0.2
# 5        setosa           5.4          3.9           1.7          0.4
# 6        setosa           4.6          3.4           1.4          0.3
# 7        setosa           5.0          3.4           1.5          0.2
# 8        setosa           4.4          2.9           1.4          0.2
# 9        setosa           4.9          3.1           1.5          0.1
# 10       setosa           5.4          3.7           1.5          0.2
# 11       setosa           4.8          3.4           1.6          0.2
# ...

# %% [markdown]
# # *** Using the Titanic dataset ***
#
#
# ### Use the function defined in acquire.py to load the Titanic data.

# %%
from acquire import get_titanic_data
titanic_db = get_titanic_data()
titanic_db = titanic_db
titanic_db.sample(3)
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch    fare  \
# 293           293         0       3  female  24.0      0      0   8.850
# 92             92         0       1    male  46.0      1      0  61.175
# 142           142         1       3  female  24.0      1      0  15.850
#
#     embarked  class deck  embark_town  alone
# 293        S  Third  NaN  Southampton      1
# 92         S  First    E  Southampton      0
# 142        S  Third  NaN  Southampton      0

# %%
titanic_db.columns
# Out:
# Index(['passenger_id', 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'deck', 'embark_town', 'alone'],
#       dtype='object')

# %% [markdown]
# ### Drop any unnecessary, unhelpful, or duplicated columns.

# %%
titanic_db = titanic_db.drop_duplicates()

titanic_db = titanic_db.drop(columns=['deck', 'age', 'embark_town', 'class'])
titanic_db.shape
# Out:
# (891, 9)

# %%
titanic_db.sample(3)
# Out:
#      passenger_id  survived  pclass     sex  sibsp  parch     fare embarked  \
# 371           371         0       3    male      1      0   6.4958        S
# 678           678         0       3  female      1      6  46.9000        S
# 745           745         0       1    male      1      1  71.0000        S
#
#      alone
# 371      0
# 678      0
# 745      0

# %% [markdown]
# ### Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.

# %%
pd.get_dummies(titanic_db.sex).astype(int)

dummy_df = pd.get_dummies(titanic_db[['sex', 'embarked']], drop_first=True).astype(int)
dummy_df
# Out:
#      sex_male  embarked_Q  embarked_S
# 0           1           0           1
# 1           0           0           0
# 2           0           0           1
# 3           0           0           1
# 4           1           0           1
# ..        ...         ...         ...
# 886         1           0           1
# 887         0           0           1
# 888         0           0           1
# 889         1           0           0
# 890         1           1           0
#
# [891 rows x 3 columns]

# %%
titanic_db = pd.concat([titanic_db, dummy_df], axis=1)
titanic_db.sample(10)
# Out:
#      passenger_id  survived  pclass     sex  sibsp  parch      fare embarked  \
# 852           852         0       3  female      1      1   15.2458        C
# 532           532         0       3    male      1      1    7.2292        C
# 30             30         0       1    male      0      0   27.7208        C
# 152           152         0       3    male      0      0    8.0500        S
# 504           504         1       1  female      0      0   86.5000        S
# 668           668         0       3    male      0      0    8.0500        S
# 844           844         0       3    male      0      0    8.6625        S
# 292           292         0       2    male      0      0   12.8750        C
# 74             74         1       3    male      0      0   56.4958        S
# 537           537         1       1  female      0      0  106.4250        C
#
#      alone  sex_male  embarked_Q  embarked_S
# 852      0         0           0           0
# ...

# %%
def prep_titanic(df):
    df.drop(columns=['deck', 'age', 'embark_town', 'class'])
    dummy_df = pd.get_dummies(df[['sex','embarked']], drop_first=True)
    df = pd.concat([df, dummy_df], axis=1)
    return df

# %%
prep_titanic(titanic_db)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 prep_titanic(titanic_db)
#
# Cell In[16], line 2, in prep_titanic(df)
#       1 def prep_titanic(df):
# ----> 2     df.drop(columns=['deck', 'age', 'embark_town', 'class'])
#       3     dummy_df = pd.get_dummies(df[['sex','embarked']], drop_first=True)
#       4     df = pd.concat([df, dummy_df], axis=1)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# ...

# %% [markdown]
# # Using the Telco dataset
#
# ### Use the function defined in acquire.py to load the Telco data.

# %%
ac.get_telco_data()
telco_db = ac.get_telco_data()
telco_db.sample(3)
# Out:
#       payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 6788                1                         2                 1  9633-XQABV
# 4005                3                         1                 1  5649-TJHOV
# 5055                3                         1                 2  7108-DGVUU
#
#       gender  senior_citizen partner dependents  tenure phone_service  ...  \
# 6788  Female               0      No         No       3           Yes  ...
# 4005    Male               1     Yes         No      27            No  ...
# 5055  Female               1     Yes         No      21           Yes  ...
#
#      tech_support streaming_tv streaming_movies paperless_billing  \
# 6788           No           No               No               Yes
# 4005           No           No              Yes                No
# 5055           No           No              Yes                No
#
#      monthly_charges total_charges churn   contract_type  \
# ...

# %% [markdown]
# ### Drop any unnecessary, unhelpful, or duplicated columns.
# ### This could mean dropping foreign key columns but keeping the corresponding string values, for example.

# %%
# crosstab payment time and payment type ID 
# looks like they referance the same thing so we can drop them 

# contract type and contract type id 
# looks like they referance the same thing so we can drop them

# %%
telco_db.describe().T
# Out:
#                            count       mean        std    min   25%    50%  \
# payment_type_id           7043.0   2.315633   1.148907   1.00   1.0   2.00
# internet_service_type_id  7043.0   1.872923   0.737796   1.00   1.0   2.00
# contract_type_id          7043.0   1.690473   0.833755   1.00   1.0   1.00
# senior_citizen            7043.0   0.162147   0.368612   0.00   0.0   0.00
# tenure                    7043.0  32.371149  24.559481   0.00   9.0  29.00
# monthly_charges           7043.0  64.761692  30.090047  18.25  35.5  70.35
#
#                             75%     max
# payment_type_id            3.00    4.00
# internet_service_type_id   2.00    3.00
# contract_type_id           2.00    3.00
# senior_citizen             0.00    1.00
# tenure                    55.00   72.00
# monthly_charges           89.85  118.75

# %%
# how many null values are there 

telco_db.isnull().sum()

# 1526 null values in internet_service_type
# Out:
# payment_type_id                0
# internet_service_type_id       0
# contract_type_id               0
# customer_id                    0
# gender                         0
# senior_citizen                 0
# partner                        0
# dependents                     0
# tenure                         0
# phone_service                  0
# multiple_lines                 0
# online_security                0
# online_backup                  0
# device_protection              0
# tech_support                   0
# streaming_tv                   0
# streaming_movies               0
# paperless_billing              0
# monthly_charges                0
# total_charges                  0
# churn                          0
# contract_type                  0
# internet_service_type       1526
# payment_type                   0
# dtype: int64

# %%
telco_db.info()

# all the column names make sence
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   payment_type_id           7043 non-null   int64
#  1   internet_service_type_id  7043 non-null   int64
#  2   contract_type_id          7043 non-null   int64
#  3   customer_id               7043 non-null   object
#  4   gender                    7043 non-null   object
#  5   senior_citizen            7043 non-null   int64
#  6   partner                   7043 non-null   object
#  7   dependents                7043 non-null   object
#  8   tenure                    7043 non-null   int64
#  9   phone_service             7043 non-null   object
#  10  multiple_lines            7043 non-null   object
#  11  online_security           7043 non-null   object
#  12  online_backup             7043 non-null   object
# ...

# %%
#find only numeric columns
num_col = telco_db.select_dtypes(include='number').columns
num_col

# 6 out of 23 are number columns
# Out:
# Index(['payment_type_id', 'internet_service_type_id', 'contract_type_id',
#        'senior_citizen', 'tenure', 'monthly_charges'],
#       dtype='object')

# %%
#plot distributions of numeric columns
for col in num_col:
    print(col)
    plt.hist(telco_db[col])
    plt.title(col)
    plt.show()
# Out:
# payment_type_id
# internet_service_type_id
# contract_type_id
# senior_citizen
# tenure
# monthly_charges

# %%
#find only string columns
str_col = telco_db.select_dtypes(exclude='number').columns
str_col

# 18 out of 23 columns are string columns
# Out:
# Index(['customer_id', 'gender', 'partner', 'dependents', 'phone_service',
#        'multiple_lines', 'online_security', 'online_backup',
#        'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies',
#        'paperless_billing', 'total_charges', 'churn', 'contract_type',
#        'internet_service_type', 'payment_type'],
#       dtype='object')

# %%
#also see the null values in value counts
# I know its this columns from the isnull function 
telco_db.internet_service_type.value_counts(dropna=False)
# Out:
# internet_service_type
# Fiber optic    3096
# DSL            2421
# NaN            1526
# Name: count, dtype: int64

# %%
#plot distributions of string columns
for col in str_col:
    print(col)
    print(telco_db[col].value_counts())
    print(telco_db[col].value_counts(normalize=True)) #percentage
    telco_db[col].value_counts(dropna=False).sort_index().plot.bar()
    plt.show()
    print()
# Out:
# customer_id
# customer_id
# 0002-ORFBO    1
# 6616-AALSR    1
# 6625-UTXEW    1
# 6625-IUTTT    1
# 6625-FLENO    1
#              ..
# 3352-RICWQ    1
# 3352-ALMCK    1
# 3351-NQLDI    1
# 3351-NGXYI    1
# 9995-HOTOH    1
# Name: count, Length: 7043, dtype: int64
# customer_id
# 0002-ORFBO    0.000142
# 6616-AALSR    0.000142
# 6625-UTXEW    0.000142
# 6625-IUTTT    0.000142
# 6625-FLENO    0.000142
#                 ...
# 3352-RICWQ    0.000142
# 3352-ALMCK    0.000142
# 3351-NQLDI    0.000142
# 3351-NGXYI    0.000142
# 9995-HOTOH    0.000142
# Name: proportion, Length: 7043, dtype: float64
# gender
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64
# gender
# Male      0.504756
# Female    0.495244
# Name: proportion, dtype: float64
# partner
# partner
# No     3641
# Yes    3402
# Name: count, dtype: int64
# partner
# No     0.516967
# Yes    0.483033
# Name: proportion, dtype: float64
# dependents
# dependents
# No     4933
# Yes    2110
# ...

# %%
#look at data
telco_db.head()
# Out:
#    payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                2                         1                 2  0002-ORFBO
# 1                2                         1                 1  0003-MKNFE
# 2                1                         2                 1  0004-TLHLJ
# 3                1                         2                 1  0011-IGKFF
# 4                2                         2                 1  0013-EXCHZ
#
#    gender  senior_citizen partner dependents  tenure phone_service  ...  \
# 0  Female               0     Yes        Yes       9           Yes  ...
# 1    Male               0      No         No       9           Yes  ...
# 2    Male               0      No         No       4           Yes  ...
# 3    Male               1     Yes         No      13           Yes  ...
# 4  Female               1     Yes         No       3           Yes  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# ...

# %%
# shows no duplicated costomers 

telco_db.customer_id.duplicated().sum()
# Out:
# 0

# %%
telco_db.dtypes
# Out:
# payment_type_id               int64
# internet_service_type_id      int64
# contract_type_id              int64
# customer_id                  object
# gender                       object
# senior_citizen                int64
# partner                      object
# dependents                   object
# tenure                        int64
# phone_service                object
# multiple_lines               object
# online_security              object
# online_backup                object
# device_protection            object
# tech_support                 object
# streaming_tv                 object
# streaming_movies             object
# paperless_billing            object
# monthly_charges             float64
# total_charges                object
# churn                        object
# contract_type                object
# internet_service_type        object
# payment_type                 object
# dtype: object

# %%
telco_db.head()
# Out:
#    payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                2                         1                 2  0002-ORFBO
# 1                2                         1                 1  0003-MKNFE
# 2                1                         2                 1  0004-TLHLJ
# 3                1                         2                 1  0011-IGKFF
# 4                2                         2                 1  0013-EXCHZ
#
#    gender  senior_citizen partner dependents  tenure phone_service  ...  \
# 0  Female               0     Yes        Yes       9           Yes  ...
# 1    Male               0      No         No       9           Yes  ...
# 2    Male               0      No         No       4           Yes  ...
# 3    Male               1     Yes         No      13           Yes  ...
# 4  Female               1     Yes         No       3           Yes  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# ...

# %%
telco_db.isnull().sum()
# Out:
# payment_type_id                0
# internet_service_type_id       0
# contract_type_id               0
# customer_id                    0
# gender                         0
# senior_citizen                 0
# partner                        0
# dependents                     0
# tenure                         0
# phone_service                  0
# multiple_lines                 0
# online_security                0
# online_backup                  0
# device_protection              0
# tech_support                   0
# streaming_tv                   0
# streaming_movies               0
# paperless_billing              0
# monthly_charges                0
# total_charges                  0
# churn                          0
# contract_type                  0
# internet_service_type       1526
# payment_type                   0
# dtype: int64

# %%
# Isolate the values 

telco_db.isnull().sum() [telco_db.isnull().sum() > 0]
# Out:
# internet_service_type    1526
# dtype: int64

# %%
#get percent of nulls
telco_db.isna().sum()[telco_db.isna().sum() > 0] / len(telco_db)
# Out:
# internet_service_type    0.216669
# dtype: float64

# %%
# Check out the counts
telco_db.internet_service_type.value_counts(dropna= False)
# Out:
# internet_service_type
# Fiber optic    3096
# DSL            2421
# NaN            1526
# Name: count, dtype: int64

# %%
# fill in the NA values with a string 

telco_db['internet_service_type'] = telco_db['internet_service_type'].fillna('No internet')

# %%
# verify 

telco_db.sample(4)
# Out:
#       payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 6503                1                         1                 3  9225-BZLNZ
# 5693                4                         2                 1  8020-BWHYL
# 3351                2                         3                 3  4779-ZGICK
# 2499                3                         2                 1  3572-UOLYZ
#
#       gender  senior_citizen partner dependents  tenure phone_service  ...  \
# 6503    Male               0     Yes         No      72           Yes  ...
# 5693  Female               1      No         No      15           Yes  ...
# 3351    Male               0     Yes        Yes      48           Yes  ...
# 2499  Female               0      No        Yes      46           Yes  ...
#
#              tech_support         streaming_tv     streaming_movies  \
# 6503                   No                  Yes                  Yes
# ...

# %%
# multipul_lines, online_security, online_backup, device_protection
telco_db.device_protection
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042    Yes
# Name: device_protection, Length: 7043, dtype: object

# %%
def dummy_var(col):
    pd.get_dummies(col).astype(int)
    return pd.get_dummies(col, drop_first=True).head().astype(int)

# %%
telco_db['gender'] = telco_db.gender.map('Male': 1, 'female': 0)
# do the same for the rest of the variables
# map only works for 1 or 0 only two options

# %%
dummy_var(telco_db.gender)
# Out:
#    Male
# 0     0
# 1     1
# 2     1
# 3     1
# 4     0

# %%
dummy_var(telco_db.partner)
# Out:
#    Yes
# 0    1
# 1    0
# 2    0
# 3    1
# 4    1

# %%
dummy_var(telco_db.dependents)
# Out:
#    Yes
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   payment_type_id           7043 non-null   int64
#  1   internet_service_type_id  7043 non-null   int64
#  2   contract_type_id          7043 non-null   int64
#  3   customer_id               7043 non-null   object
#  4   gender                    7043 non-null   object
#  5   senior_citizen            7043 non-null   int64
#  6   partner                   7043 non-null   object
#  7   dependents                7043 non-null   object
#  8   tenure                    7043 non-null   int64
#  9   phone_service             7043 non-null   object
#  10  multiple_lines            7043 non-null   object
#  11  online_security           7043 non-null   object
#  12  online_backup             7043 non-null   object
# ...

# %%
def prep_telco(df):
    telco_db['internet_service_type'] = telco_db['internet_service_type'].fillna('No internet')    
    dummy_df = pd.get_dummies(df[['gender','partner', 'dependents', 'phone_service', 'tech_support', 'streaming_tv', 'streaming_movies', 'paperless_billing', 'churn', 'contract_type', 'internet_service_type', 'payment_type', 'multiple_lines', 'online_backup', 'online_security', 'device_protection']], drop_first=True).astype(int)
    df = pd.concat([df, dummy_df], axis=1)
    return df

# %%
prep_telco(telco_db).info()
# turn total charges into a float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 51 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   payment_type_id                        7043 non-null   int64
#  1   internet_service_type_id               7043 non-null   int64
#  2   contract_type_id                       7043 non-null   int64
#  3   customer_id                            7043 non-null   object
#  4   gender                                 7043 non-null   object
#  5   senior_citizen                         7043 non-null   int64
#  6   partner                                7043 non-null   object
#  7   dependents                             7043 non-null   object
#  8   tenure                                 7043 non-null   int64
#  9   phone_service                          7043 non-null   object
# ...

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # ************************ Telco ****************************

# %%
def prep_telco(df):
    telco_db['internet_service_type'] = telco_db['internet_service_type'].fillna('No internet')    
    dummy_df = pd.get_dummies(df[['gender','partner', 'dependents', 'phone_service', 'tech_support', 'streaming_tv', 'streaming_movies', 'paperless_billing', 'churn', 'contract_type', 'internet_service_type', 'payment_type', 'multiple_lines', 'online_backup', 'online_security', 'device_protection']], drop_first=True).astype(int)
    df = pd.concat([df, dummy_df], axis=1)
    return df

# %%
prep_telco_data = prep_telco(telco_db)

# %%
#first split
train, test = train_test_split(prep_telco_data, #dataframe
                random_state=123, #setting my random seed
                test_size=0.20, #setting the size of my test df
                stratify=prep_telco_db.internet_service_type #stratifying on my target variable
)

# %%
# Observe split
print(f'Prepared df: {prep_telco_data.shape}')
print()
print(f'Train: {train.shape}')
print(f'Test: {test.shape}')
# Out:
# Prepared df: (7043, 51)
#
# Train: (5634, 51)
# Test: (1409, 51)

# %%
#what percent is our train set?
len(train) / len(prep_telco_data)
# Out:
# 0.7999432060201619

# %%
#what percent is our test set?
len(test) / len(prep_telco_data)
# Out:
# 0.20005679397983814

# %%
#second split
train, validate = train_test_split(train, 
                random_state=123,
                 test_size=.25,
                 stratify= train.internet_service_type
)

# %%
# Observe split
print(f'Prepared df: {prep_telco_data.shape}')
print()
print(f'Train: {train.shape}')
print(f'Validate: {validate.shape}')
print(f'Test: {test.shape}')
# Out:
# Prepared df: (7043, 51)
#
# Train: (4225, 51)
# Validate: (1409, 51)
# Test: (1409, 51)

# %%
def split_telco_data(df):
    train_validate, test = train_test_split(df, test_size=.2, random_state=123, stratify=df.internet_service_type)
    train, validate = train_test_split(train_validate, 
                                       test_size=.3, 
                                       random_state=123, 
                                       stratify=train_validate.internet_service_type)
    return train, validate, test

# %%
train, validate, test = split_telco_data(prep_telco_data)
print(f'train -> {train.shape}')
print(f'validate -> {validate.shape}')
print(f'test -> {test.shape}')
# Out:
# train -> (3943, 51)
# validate -> (1691, 51)
# test -> (1409, 51)

# %% [markdown]
# # ****************************** titanic ********************************

# %%
def prep_titanic(df):
    df.drop_duplicates()
    df.drop(columns=['deck', 'embark_town', 'class'])
    dummy_df = pd.get_dummies(df[['sex','embarked']], drop_first=True)
    df = pd.concat([df, dummy_df], axis=1)
    return df

# %%
prep_titanic_data = prep_titanic(titanic_db)

# %%
train, test = train_test_split(prep_titanic_data, #dataframe
                random_state=123, #setting my random seed
                test_size=0.20, #setting the size of my test df
                stratify=prep_titanic_data.survived #stratifying on my target variable
)

# %%
# Observe split
print(f'Prepared df: {prep_titanic_data.shape}')
print()
print(f'Train: {train.shape}')
print(f'Test: {test.shape}')
# Out:
# Prepared df: (891, 16)
#
# Train: (712, 16)
# Test: (179, 16)

# %%
#what percent is our train set?
len(train) / len(prep_titanic_data)
# Out:
# 0.7991021324354658

# %%
#what percent is our test set?
len(test) / len(prep_titanic_data)
# Out:
# 0.20089786756453423

# %%
#second split
train, validate = train_test_split(train, 
                random_state=123,
                 test_size=.25,
                 stratify= train.survived
)

# %%
# Observe split
print(f'Prepared df: {prep_titanic_data.shape}')
print()
print(f'Train: {train.shape}')
print(f'Validate: {validate.shape}')
print(f'Test: {test.shape}')
# Out:
# Prepared df: (891, 16)
#
# Train: (534, 16)
# Validate: (178, 16)
# Test: (179, 16)

# %%
def split_titanic_data(df):
    '''
    take in a DataFrame and return train, validate, and test DataFrames; stratify on survived.
    return train, validate, test DataFrames.
    '''
    train_validate, test = train_test_split(df, test_size=.2, random_state=123, stratify=df.survived)
    train, validate = train_test_split(train_validate, 
                                       test_size=.3, 
                                       random_state=123, 
                                       stratify=train_validate.survived)
    return train, validate, test

# %%
train, validate, test = split_titanic_data(prep_titanic_data)
print(f'train -> {train.shape}')
print(f'validate -> {validate.shape}')
print(f'test -> {test.shape}')
# Out:
# train -> (498, 16)
# validate -> (214, 16)
# test -> (179, 16)

# %% [markdown]
# # ************************************** iris ***************************************

# %%
def prep_iris(df):
    df = df.drop(columns= ['species_id', 'measurement_id'])
    df.rename(columns={'species_name': 'species'})
    dummy_df = pd.get_dummies(df[['species']], drop_first=True).astype(int)
    df = pd.concat([df, dummy_df], axis=1)
    return df

# %%
prep_iris_data = prep_iris(iris_db)

# %%
train, test = train_test_split(prep_iris_data, #dataframe
                random_state=123, #setting my random seed
                test_size=0.20, #setting the size of my test df
                stratify=prep_iris_data.species #stratifying on my target variable
)

# %%
# Observe split
print(f'Prepared df: {prep_iris_data.shape}')
print()
print(f'Train: {train.shape}')
print(f'Test: {test.shape}')
# Out:
# Prepared df: (150, 7)
#
# Train: (120, 7)
# Test: (30, 7)

# %%
#what percent is our train set?
len(train) / len(prep_iris_data)
# Out:
# 0.8

# %%
#what percent is our test set?
len(test) / len(prep_iris_data)
# Out:
# 0.2

# %%
#second split
train, validate = train_test_split(train, 
                random_state=123,
                 test_size=.25,
                 stratify= train.species
)

# %%
# Observe split
print(f'Prepared df: {prep_iris_data.shape}')
print()
print(f'Train: {train.shape}')
print(f'Validate: {validate.shape}')
print(f'Test: {test.shape}')
# Out:
# Prepared df: (150, 7)
#
# Train: (90, 7)
# Validate: (30, 7)
# Test: (30, 7)

# %%
def split_iris_data(df):
    '''
    take in a DataFrame and return train, validate, and test DataFrames; stratify on survived.
    return train, validate, test DataFrames.
    '''
    train_validate, test = train_test_split(df, test_size=.2, random_state=123, stratify=df.species)
    train, validate = train_test_split(train_validate, 
                                       test_size=.3, 
                                       random_state=123, 
                                       stratify=train_validate.species)
    return train, validate, test

# %%
def split_function(df: pd.DataFrame, target_varible: str) -> int:
    train, test = train_test_split(df,
                                   random_state=123,
                                   test_size=.20,
                                   stratify= df[target_varible])
    
    train, validate = train_test_split(train,
                                   random_state=123,
                                   test_size=.25,
                                   stratify= train[target_varible])
    return train, validate, test

# %%
train_iris, validate_iris, test_iris = split_function(iris, 'species')
print(f'train -> {train_iris.shape}')
print(f'validate -> {validate_iris.shape}')
print(f'test -> {test_iris.shape}')
# Out:
# train -> (90, 7)
# validate -> (30, 7)
# test -> (30, 7)

# %%
train, validate, test = split_iris_data(prep_iris_data)
print(f'train -> {train.shape}')
print(f'validate -> {validate.shape}')
print(f'test -> {test.shape}')
# Out:
# train -> (84, 7)
# validate -> (36, 7)
# test -> (30, 7)

# %% [markdown]
# # ---------------------------- Exploratory Data Analysis ---------------------------

# %% [markdown]
# # Section 1 - iris_db: Using iris data from our mySQL server and the methods used in the lesson above:
#
# ## Acquire, prepare & split your data.

# %%
import acquire as ac
import prepare as pr 

iris = ac.get_iris_data() # pulls data from SQL
iris = pr.prep_iris(iris) # cleans the data and adds featurs I want
train_iris, validate_iris, test_iris = split_function(iris, 'species') # splits the data into train test and validate 
print(f'train -> {train_iris.shape}')
print(f'validate -> {validate_iris.shape}')
print(f'test -> {test_iris.shape}')
# Out:
# train -> (90, 7)
# validate -> (30, 7)
# test -> (30, 7)

# %% [markdown]
# # Question 2
#
# ## Univariate Stats
#
# ## For each measurement type (quantitative variable): create a histogram, boxplot, & compute descriptive statistics (using .describe()).

# %%
train_iris.sepal_length.hist()
plt.title('sepal length')
plt.show()

# %%
train_iris.sepal_length.plot.box()
# Out:
# <Axes: >

# %%
train_iris.sepal_length.describe()
# Out:
# count    90.000000
# mean      5.875556
# std       0.792282
# min       4.400000
# 25%       5.225000
# 50%       5.800000
# 75%       6.400000
# max       7.900000
# Name: sepal_length, dtype: float64

# %%
train_iris.sepal_width.hist()
plt.title('sepal width')
plt.show()

# %%
train_iris.sepal_width.plot.box()
plt.title('sepal width')
plt.show()

# %%
test_iris.sepal_width.describe()
# Out:
# count    30.000000
# mean      3.070000
# std       0.447329
# min       2.200000
# 25%       2.925000
# 50%       3.000000
# 75%       3.275000
# max       4.200000
# Name: sepal_width, dtype: float64

# %%
train_iris.petal_length.hist()
plt.title('Petal length')
plt.show()

# %%
train_iris.petal_length.plot.box()
plt.show()

# %%
train_iris.petal_length.describe()
# Out:
# count    90.000000
# mean      3.782222
# std       1.742114
# min       1.200000
# 25%       1.600000
# 50%       4.250000
# 75%       5.100000
# max       6.900000
# Name: petal_length, dtype: float64
